# %% [markdown]
# Importing libraries we need, setting up an workind directory

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("C:/Users/baakh/OneDrive/Documents/GitHub/business-data-analysis-report/Data Research.xlsx")
df.head()
# Out:
#   InvoiceNo StockCode                     Description  Quantity  \
# 0    536365    84029E  RED WOOLLY HOTTIE WHITE HEART.         6
# 1    536367     84879   ASSORTED COLOUR BIRD ORNAMENT        32
# 2    536367     21755        LOVE BUILDING BLOCK WORD         3
# 3    536368     22914    BLUE COAT RACK PARIS FASHION         3
# 4    536373    84406B  CREAM CUPID HEARTS COAT HANGER         8
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2019-12-01 08:26:00       3.39     17850.0  United Kingdom
# 1 2019-12-01 08:34:00       1.69     13047.0  United Kingdom
# 2 2019-12-01 08:34:00       5.95     13047.0  United Kingdom
# 3 2019-12-01 08:34:00       4.95     13047.0  United Kingdom
# 4 2019-12-01 09:02:00       2.75     17850.0  United Kingdom

# %% [markdown]
# Let's check data integrity

# %%
df.describe(include='all')
# Out:
# C:\Users\baakh\AppData\Local\Temp\ipykernel_4716\2884002236.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe(include='all')
#         InvoiceNo StockCode                         Description      Quantity  \
# count     54214.0     54214                               54080  54214.000000
# unique    14877.0      3351                                3401           NaN
# top      573585.0    85123A  WHITE HANGING HEART T-LIGHT HOLDER           NaN
# freq        127.0       237                                 243           NaN
# first         NaN       NaN                                 NaN           NaN
# last          NaN       NaN                                 NaN           NaN
# mean          NaN       NaN                                 NaN      9.610802
# std           NaN       NaN                                 NaN     57.358422
# min           NaN       NaN                                 NaN  -9600.000000
# 25%           NaN       NaN                                 NaN      1.000000
# 50%           NaN       NaN                                 NaN      3.000000
# 75%           NaN       NaN                                 NaN     10.000000
# max           NaN       NaN                                 NaN   2400.000000
#
#                 InvoiceDate     UnitPrice    CustomerID         Country
# count                 54214  54214.000000  40643.000000           54214
# unique                14058           NaN           NaN              37
# top     2020-10-31 14:41:00           NaN           NaN  United Kingdom
# freq                    127           NaN           NaN           49602
# first   2019-12-01 08:26:00           NaN           NaN             NaN
# last    2020-12-09 12:50:00           NaN           NaN             NaN
# mean                    NaN      4.307341  15283.422803             NaN
# std                     NaN     47.834496   1707.982278             NaN
# min                     NaN      0.000000  12347.000000             NaN
# 25%                     NaN      1.250000  13969.000000             NaN
# 50%                     NaN      2.080000  15152.000000             NaN
# 75%                     NaN      4.130000  16775.000000             NaN
# max                     NaN   6930.000000  18287.000000             NaN

# %% [markdown]
# So here we can understand:
# 1) Some values are missing. Other way "count" would be equal in all columns. That way we are having "null" values in "description" and "Customer_id"
# 2) Also we are have some anomalies. We are having negative and too high quantity here. Also in some places UnitPrice = 0 or too much.

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
plt.subplots_adjust(wspace=0.5)

df.boxplot(column='Quantity', ax=ax1)
ax1.set_title('Quantity')

df.boxplot(column='UnitPrice', ax=ax2)
ax2.set_title('Unit Price')
plt.show()

# %% [markdown]
# Here we can see our quantity with 1 outlier and unit price with at least 2. It is better to check that data

# %%
df[df['Quantity']<0]
# Out:
#       InvoiceNo StockCode                        Description  Quantity  \
# 19      C536383    35004C    SET OF 3 COLOURED  FLYING DUCKS        -1
# 30      C536391     21983   PACK OF 12 BLUE PAISLEY TISSUES        -24
# 31      C536391     21980  PACK OF 12 RED RETROSPOT TISSUES        -24
# 202     C536548     20957       PORCELAIN HANGING BELL SMALL        -1
# 375     C536642     21463               MIRRORED DISCO BALL         -1
# ...         ...       ...                                ...       ...
# 53704   C581229    79191C        RETRO PLASTIC ELEPHANT TRAY       -24
# 53705   C581229     21507            ELEPHANT BIRTHDAY CARD        -12
# 53765   C581322     22666    RECIPE BOX PANTRY YELLOW DESIGN        -1
# 53770   C581330     22959             WRAP CHRISTMAS VILLAGE       -25
# 53998   C581465     22171   3 HOOK PHOTO SHELF ANTIQUE WHITE        -1
#
#               InvoiceDate  UnitPrice  CustomerID         Country
# 19    2019-12-01 09:49:00       4.65     15311.0  United Kingdom
# 30    2019-12-01 10:24:00       0.29     17548.0  United Kingdom
# 31    2019-12-01 10:24:00       0.29     17548.0  United Kingdom
# 202   2019-12-01 14:33:00       1.45     12472.0         Germany
# 375   2019-12-02 11:56:00       5.95     14390.0  United Kingdom
# ...                   ...        ...         ...             ...
# 53704 2020-12-08 10:14:00       0.85     12558.0             USA
# 53705 2020-12-08 10:14:00       0.42     12558.0             USA
# 53765 2020-12-08 11:51:00       2.95     18223.0  United Kingdom
# 53770 2020-12-08 11:57:00       0.42     15877.0  United Kingdom
# 53998 2020-12-08 18:59:00       8.50     15755.0  United Kingdom
#
# [1083 rows x 8 columns]

# %% [markdown]
# We are having too much of negative quantities, so I don't think there's any mistake. I would consult with data engineer, but anyway it is too much for a small mistake

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)

df.hist('Quantity', range=(1,10), ax=ax1)

df.hist('UnitPrice',range=(1.25,4.13), ax=ax2)
plt.show()
